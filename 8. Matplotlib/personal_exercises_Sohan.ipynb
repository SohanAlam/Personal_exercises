# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
file1 = "C:\practice_september\Personalexercises_september\8. Matplotlib\company_sales_data.csv"
data = pd.read_csv(file1)
print(data)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
x1= data['month_number'].to_list()
y1= data['total_profit'].to_list()
#print(x)
#print(y)
plt.plot(x1,y1, 'o:r', marker='o', mec='r', mfc='k', linewidth='3')
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.legend(["Profit data of last year"], loc ="lower right")
plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
x= data['month_number'].to_list()
y1= data['facecream'].to_list()
y2= data['facewash'].to_list()
y3= data['toothpaste'].to_list()
y4= data['bathingsoap'].to_list()
y5= data['shampoo'].to_list()
y6= data['moisturizer'].to_list()

#plt.plot(x1)
plt.plot(x,y1, label="facecream sale data", color='b', marker='o')
plt.plot(x,y2,label="facewash sale data", color='r', marker='*')
plt.plot(x,y3,label="toothpaste sale data", color='k', marker='x')
plt.plot(x,y4,label="bathingsoap sale data", color='m', marker='p')
plt.plot(x,y5,label="shampoo sale data", color='y', marker='s')
plt.plot(x,y6,label="moisturizer sale data", color='g', marker='p')
plt.legend(loc ="upper left")
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.figure(figsize=(10, 8))
plt.show()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
toothpaste= data['toothpaste'].to_list()
plt.plot(x,toothpaste,' ', label="toothpaste sale data", color='b', marker='o', ms='10' )
plt.legend(loc ="upper left")
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.grid()
plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
x= data['month_number'].to_list()
plt.figure(figsize=(10, 10))
x_ax =np.arange(len(x))
facecream= data['facecream'].to_list()
facewash= data['facewash'].to_list()
plt.bar(x_ax - 0.2 ,facecream,0.40 , label="facecream sales data", color='b')
plt.bar(x_ax + 0.2 ,facewash, 0.50, label="facewash sales  data", color='r')
plt.legend(loc ="upper left")
plt.xticks(x_ax, x)
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title('facewash and facecream sales data')
plt.grid()
plt.show()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
bathingsoap= data['bathingsoap'].to_list()
plt.figure(figsize=(10, 10))
plt.bar(x,bathingsoap)
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title('bathingsoap sales data')
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.figure(figsize=(10, 10))
total_profit= data['total_profit'].to_list()
plt.hist(total_profit, label='profit data')
plt.legend(loc ="upper left")
plt.xlabel("Profit range in Dollar")
plt.ylabel("Actual Profit in Dollar")
plt.title('Profit data')
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.figure(figsize=(10, 7))
x = data['total_units'].sum()
facecream = data['facecream'].sum()
face_cream = (facecream / x) * 100

facewash = data['facewash'].sum()
face_wash = (facewash / x) * 100

toothpaste= data['toothpaste'].sum()
tooth_paste = (toothpaste / x) *100



bathingsoap  = data['bathingsoap'].sum()
bathing_soap = (bathingsoap  / x)*100


shampoo = data['shampoo'].sum()
sham_poo = (shampoo / x) * 100

moisturizer = data['moisturizer'].sum()
moist_urizer = (moisturizer / x) * 100


y = [face_cream, face_wash,tooth_paste,bathing_soap,sham_poo,moist_urizer]

lab_els = ["facecream", "facewash","toothpaste","bathingsoap","shampoo","moisturizer"]
plt.pie(y,labels=lab_els,autopct='%1.0f%%')
plt.legend(loc='lower right')
plt.title('sales data')
plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.figure(figsize=(10, 7))
x1= data['month_number'].to_list()
y4= data['bathingsoap'].to_list()
plt.subplot(2, 1, 1)
plt.title('Sales data of Bathingsoap')
plt.plot(x1,y4, marker='o',ms=12,linewidth =8,color='k')


x1= data['month_number'].to_list()
y2= data['facewash'].to_list()
plt.subplot(2, 1, 2)
plt.title('Sales data of a facewash')
plt.plot(x1,y2,marker='o',ms=12,linewidth =8,color='r')
plt.xlabel("Month Number")
plt.ylabel("Sales units number")

plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
plt.figure(figsize=(10, 7))
x= data['month_number'].to_list()
y1= data['facecream'].to_list()
y2= data['facewash'].to_list()
y3= data['toothpaste'].to_list()
y4= data['bathingsoap'].to_list()
y5= data['shampoo'].to_list()
y6= data['moisturizer'].to_list()


plt.plot([],[],color='g', label='facecream', linewidth=3)
plt.plot([],[],color='b', label='facewash', linewidth=3)
plt.plot([],[],color='r', label='toothpaste', linewidth=3)
plt.plot([],[],color='k', label='bathingsoap', linewidth=3)
plt.plot([],[],color='m', label='shampoo', linewidth=3)
plt.plot([],[],color='y', label='moisturizer', linewidth=3)


plt.stackplot(x, y1, y2, y3, y4,y5,y5)
#plt.stackplot()
plt.xlabel('month number')
plt.ylabel('Total Sales')
plt.title('All products sale')
plt.legend(loc='upper left')
plt.show()
