# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("dataset_halfSecondWindow.csv")
df.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0      id    time  activityrecognition#0  \
# 0               0  156661     3.0                    NaN
# 1               1  156662     4.0                    NaN
# 2               2  156663     5.0                    NaN
# 3               3  156664     6.0                    NaN
# 4               4  156665     7.0                    NaN
# ...           ...     ...     ...                    ...
# 62580       62580   82695  4066.0                    NaN
# 62581       62581   77608   604.0                    NaN
# 62582       62582   85219  1341.0                    NaN
# 62583       62583   69368  1186.0                    NaN
# 62584       62584   84508   630.0                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                       62.0                          10.053802
# 1                       62.0                          10.687402
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'activityrecognition#0',
#        'activityrecognition#1', 'android.sensor.accelerometer#mean',
#        'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max',
#        'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# id                           0
# time                         0
# activityrecognition#0    62585
# activityrecognition#1        0
#                          ...
# speed#min                25920
# speed#max                25920
# speed#std                60894
# target                       0
# user                         0
# Length: 71, dtype: int64

# %%
cdf = df.fillna(0)
cdf
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 0               0  156661     3.0                    0.0
# 1               1  156662     4.0                    0.0
# 2               2  156663     5.0                    0.0
# 3               3  156664     6.0                    0.0
# 4               4  156665     7.0                    0.0
# ...           ...     ...     ...                    ...
# 62580       62580   82695  4066.0                    0.0
# 62581       62581   77608   604.0                    0.0
# 62582       62582   85219  1341.0                    0.0
# 62583       62583   69368  1186.0                    0.0
# 62584       62584   84508   630.0                    0.0
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                       62.0                          10.053802
# 1                       62.0                          10.687402
# 2                       62.0                          11.816800
# ...

# %%
df1= cdf[['activityrecognition#1', 'android.sensor.accelerometer#mean', 'android.sensor.game_rotation_vector#mean', 'sound#mean', 'android.sensor.magnetic_field#mean']].values
df1[0:5]
# Out:
# array([[62.        , 10.05380207,  0.62907566,  0.        , 26.2943063 ],
#        [62.        , 10.68740236,  0.57783939,  0.        , 26.29512545],
#        [62.        , 11.81680046,  0.65151128,  0.        , 27.04884344],
#        [62.        ,  9.40131152,  0.71322565,  0.        , 25.87859055],
#        [62.        , 10.38985134,  0.70737545,  0.        , 25.59966283]])

# %%
y = cdf["target"]
y[0:5]
# Out:
# 0    Bus
# 1    Bus
# 2    Bus
# 3    Bus
# 4    Bus
# Name: target, dtype: object

# %%
# from sklearn import preprocessing
# target_new = preprocessing.LabelEncoder()
# target_new.fit(['Car','Bus','Train','Still','Walking'])
# X[:,1] = target_new.transform(X[:,1]) 
# X[0:5]

# %%
cdf['target'] = pd.factorize(cdf['target'])[0] + 1
cdf
# Out:
#        Unnamed: 0      id    time  activityrecognition#0  \
# 0               0  156661     3.0                    0.0
# 1               1  156662     4.0                    0.0
# 2               2  156663     5.0                    0.0
# 3               3  156664     6.0                    0.0
# 4               4  156665     7.0                    0.0
# ...           ...     ...     ...                    ...
# 62580       62580   82695  4066.0                    0.0
# 62581       62581   77608   604.0                    0.0
# 62582       62582   85219  1341.0                    0.0
# 62583       62583   69368  1186.0                    0.0
# 62584       62584   84508   630.0                    0.0
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                       62.0                          10.053802
# 1                       62.0                          10.687402
# 2                       62.0                          11.816800
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler(df1)
# df2 = scaler.fit(df1)
# df2

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
activity_recognition = scaling.fit_transform(cdf[['activityrecognition#1']])
accelerometer = scaling.fit_transform(cdf[['android.sensor.accelerometer#mean']])
game_rotation_vector = scaling.fit_transform(cdf[['android.sensor.game_rotation_vector#mean']])
sound = scaling.fit_transform(cdf[['sound#mean']])
magnetic_field = scaling.fit_transform(cdf[['android.sensor.magnetic_field#mean']])

# %%
df3 = cdf.target
df3
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 62580    5
# 62581    5
# 62582    5
# 62583    5
# 62584    5
# Name: target, Length: 62585, dtype: int64

# %%
column_names = ['activityrecognition#1','android.sensor.accelerometer#mean']#,'game_rotation_vector','sound','magnetic_field']

df4=cdf.loc[:,column_names]
#df4 = df4.insert(loc=column_location,column='column_names',value=new_column_values)
#df4
df4
# Out:
#        activityrecognition#1  android.sensor.accelerometer#mean
# 0                       62.0                          10.053802
# 1                       62.0                          10.687402
# 2                       62.0                          11.816800
# 3                       62.0                           9.401312
# 4                       62.0                          10.389851
# ...                      ...                                ...
# 62580                   51.0                          10.105329
# 62581                  100.0                           9.544118
# 62582                  100.0                          14.258467
# 62583                   90.0                          10.726491
# 62584                  100.0                          15.892297
#
# [62585 rows x 2 columns]
